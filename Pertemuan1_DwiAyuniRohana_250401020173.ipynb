# %% [markdown]
# <a href="https://colab.research.google.com/github/DwiAyuniRohana/data-science-2025/blob/main/Pertemuan1_DwiAyuniRohana_250401020173.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nama:** Dwi Ayuni Rohana
#
# **NIM:** 250401020173
#
# **Kelas:** IF405
#
# **Prodi:** Informatika

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
print(f"Nama    : {'Dwi Ayuni Rohana'}")
print(f"Angkatan: {2025}")
print(f"IPK     : {3.84}")
print(f"Aktif   : {aktif}")
# Out:
# Nama    : Dwi Ayuni Rohana
# Angkatan: 2025
# IPK     : 3.84
# Aktif   : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Dwi Ayuni Rohana", "Informatika", 2025)
print(hasil)
# Out:
# Hai! Saya Dwi Ayuni Rohana dari Informatika, angkatan 2025.

# %% [markdown]
# # Kesimpulan
#
# Pada praktikum ini saya mempelajari dasar-dasar penggunaan Python sebagai bahasa pemrograman untuk Data Science. Materi yang dipraktikkan meliputi penggunaan fungsi `print()`, variabel dengan berbagai tipe data, list, perulangan (`for`), serta pembuatan dan pemanggilan fungsi sederhana.
#
# Temuan utama dari praktikum ini adalah Python memungkinkan pengguna untuk menyimpan dan mengelola data dengan mudah menggunakan variabel dan struktur data seperti list. Selain itu, penggunaan fungsi dapat membantu membuat program lebih terstruktur dan dapat digunakan kembali. Praktikum juga memberikan pengenalan terhadap beberapa tools yang umum digunakan dalam Data Science, yaitu Python, Google Colab, Jupyter Notebook, dan GitHub.
#
# Keterbatasan pada praktikum ini adalah materi masih berfokus pada pengenalan dasar pemrograman dan belum mencakup pengolahan data maupun analisis menggunakan dataset nyata. Pertanyaan yang muncul adalah bagaimana konsep-konsep dasar Python yang telah dipelajari dapat diterapkan untuk melakukan analisis data, visualisasi data, dan pembangunan model Machine Learning pada pertemuan-pertemuan berikutnya.
